# %% [markdown]
# Numpy的运用

# %%
import numpy as np

# %%
x1=[1,2,3]
x2=np.array([1,2,3])
print(type(x1))
print(type(x2))
# Out:
# <class 'list'>
# <class 'numpy.ndarray'>

# %%
x1=[1,2,3]
x2=[3,6,9]
print(x1+x2)
# Out:
# [1, 2, 3, 3, 6, 9]
